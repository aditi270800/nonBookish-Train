# %%
import pandas as pd

# %%
df=pd.read_csv("tmdb_movies_data.csv")

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
print("Number of observations in the datasets :")
print("\ndf : \n",'-' * 20,len(df))
# Out:
# Number of observations in the datasets :
#
# df :
#  -------------------- 10866

# %%
print("Empty cells or Nans in the datasets :")
print("\ndf : \n",'-' * 20,df.isnull().values.any())
# Out:
# Empty cells or Nans in the datasets :
#
# df :
#  -------------------- True

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.isnull()
# Out:
#           id  imdb_id  popularity  budget  revenue  original_title   cast  \
# 0      False    False       False   False    False           False  False
# 1      False    False       False   False    False           False  False
# 2      False    False       False   False    False           False  False
# 3      False    False       False   False    False           False  False
# 4      False    False       False   False    False           False  False
# ...      ...      ...         ...     ...      ...             ...    ...
# 10861  False    False       False   False    False           False  False
# 10862  False    False       False   False    False           False  False
# 10863  False    False       False   False    False           False  False
# 10864  False    False       False   False    False           False  False
# 10865  False    False       False   False    False           False  False
#
#        homepage  director  tagline  ...  overview  runtime  genres  \
# ...

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 10819
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1992 non-null   int64
#  1   imdb_id               1992 non-null   object
#  2   popularity            1992 non-null   float64
#  3   budget                1992 non-null   int64
#  4   revenue               1992 non-null   int64
#  5   original_title        1992 non-null   object
#  6   cast                  1992 non-null   object
#  7   homepage              1992 non-null   object
#  8   director              1992 non-null   object
#  9   tagline               1992 non-null   object
#  10  keywords              1992 non-null   object
#  11  overview              1992 non-null   object
#  12  runtime               1992 non-null   int64
#  13  genres                1992 non-null   object
#  14  production_companies  1992 non-null   object
# ...

# %%
print("Empty cells or Nans in the datasets :")
print("\ndf : \n",'-' * 20,df.isnull().values.any())
# Out:
# Empty cells or Nans in the datasets :
#
# df :
#  -------------------- False

# %%
df.budget.nlargest(3).iloc[[-1]]
# Out:
# 7387    300000000
# Name: budget, dtype: int64

# %%
d=(df[df['budget'] == 300000000])[['original_title']]

# %%
d
# Out:
#                                 original_title
# 7387  Pirates of the Caribbean: At World's End

# %%
df.budget.nsmallest(3).iloc[[-1]]
# Out:
# 88    0
# Name: budget, dtype: int64

# %%
d=(df[df['budget'] == 0])[['original_title']]

# %%
d
# Out:
#                                original_title
# 30                                 Mr. Holmes
# 75             Me and Earl and the Dying Girl
# 88                                     Equals
# 95     Alvin and the Chipmunks: The Road Chip
# 132                     Shaun the Sheep Movie
# ...                                       ...
# 10328                               Body Bags
# 10567                              Caravaggio
# 10657          Beyond the Valley of the Dolls
# 10817                          The Last Waltz
# 10819                                  Hooper
#
# [546 rows x 1 columns]

# %%
d=(df[df['release_year'] == 2006])[['runtime']]

# %%
import numpy as np

# %%
np.mean(d)
# Out:
# runtime    109.967391
# dtype: float64

# %%
df.revenue.nlargest().iloc[[-1]]
# Out:
# 0    1513528810
# Name: revenue, dtype: int64

# %%
d=(df[df['revenue'] == 1513528810])[['original_title']]

# %%
d
# Out:
#    original_title
# 0  Jurassic World

# %%
df.revenue.nsmallest().iloc[[-1]]
# Out:
# 174    0
# Name: revenue, dtype: int64

# %%
d=(df[df['revenue'] == 0])[['original_title']]

# %%
d
# Out:
#                        original_title
# 67                           Survivor
# 75     Me and Earl and the Dying Girl
# 143              Brothers of the Wind
# 159                         Kung Fury
# 174                   Jenny's Wedding
# ...                               ...
# 10238              The Wrong Trousers
# 10328                       Body Bags
# 10372           Cannibal! The Musical
# 10567                      Caravaggio
# 10657  Beyond the Valley of the Dolls
#
# [546 rows x 1 columns]

# %%
df.assign(avg_words=df['original_title'].str.split().str.len()).groupby('release_year').agg({'release_year': 'count','original_title': 'count', 'avg_words': 'mean'}).tail(16)
# Out:
#               release_year  original_title  avg_words
# release_year
# 2000                    20              20   2.700000
# 2001                    19              19   2.894737
# 2002                    31              31   3.064516
# 2003                    40              40   2.750000
# 2004                    48              48   2.854167
# 2005                    72              72   2.472222
# 2006                    92              92   2.913043
# 2007                   135             135   2.874074
# 2008                   142             142   2.704225
# 2009                   192             192   2.723958
# 2010                   206             206   2.640777
# 2011                   219             219   2.785388
# 2012                   145             145   2.579310
# 2013                   128             128   2.789062
# 2014                   153             153   2.843137
# 2015                   165             165   2.581818
